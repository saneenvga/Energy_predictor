# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Energy_consumption.csv')
df.head()
# Out:
#              Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0  2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1  2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2  2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3  2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4  2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          1000 non-null   object
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   object
#  6   LightingUsage      1000 non-null   object
#  7   RenewableEnergy    1000 non-null   float64
#  8   DayOfWeek          1000 non-null   object
#  9   Holiday            1000 non-null   object
#  10  EnergyConsumption  1000 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 86.1+ KB

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          1000 non-null   datetime64[ns]
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   object
#  6   LightingUsage      1000 non-null   object
#  7   RenewableEnergy    1000 non-null   float64
#  8   DayOfWeek          1000 non-null   object
#  9   Holiday            1000 non-null   object
#  10  EnergyConsumption  1000 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(4)
# memory usage: 86.1+ KB

# %%
#df['Time'] = df['Timestamp'].dt.time

# %%
#df['Timestamp'] = df['Timestamp'].dt.date
df.head()
# Out:
#             Timestamp  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
df.rename(columns={'Timestamp':'Date_Time'},inplace=True)

# %%
df.head()
# Out:
#             Date_Time  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  RenewableEnergy  DayOfWeek Holiday  \
# 0        On           Off         2.774699     Monday      No
# 1        On            On        21.831384   Saturday      No
# 2       Off           Off         6.764672     Sunday      No
# 3       Off            On         8.623447  Wednesday      No
# 4        On           Off         3.071969     Friday      No
#
#    EnergyConsumption
# 0          75.364373
# 1          83.401855
# 2          78.270888
# 3          56.519850
# 4          70.811732

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.drop('RenewableEnergy',axis=1,inplace=True)

# %%
df.head()
# Out:
#             Date_Time  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#   HVACUsage LightingUsage  DayOfWeek Holiday  EnergyConsumption
# 0        On           Off     Monday      No          75.364373
# 1        On            On   Saturday      No          83.401855
# 2       Off           Off     Sunday      No          78.270888
# 3       Off            On  Wednesday      No          56.519850
# 4        On           Off     Friday      No          70.811732

# %%
df['HVACUsage'] = df['HVACUsage'].map({'On':1, 'Off':0})

# %%
df['LightingUsage'] = df['LightingUsage'].map({'On':1, 'Off':0})

# %%
df['Holiday'] = df['Holiday'].map({'Yes':1, 'No':0})

# %%
df['Weekend'] = df['DayOfWeek'].isin(['Saturday','Sunday']).astype(int)

# %%
df.head()
# Out:
#             Date_Time  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#    HVACUsage  LightingUsage  DayOfWeek  Holiday  EnergyConsumption  Weekend
# 0          1              0     Monday        0          75.364373        0
# 1          1              1   Saturday        0          83.401855        1
# 2          0              0     Sunday        0          78.270888        1
# 3          0              1  Wednesday        0          56.519850        0
# 4          1              0     Friday        0          70.811732        0

# %%
df['Holiday'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# Date_Time            0
# Temperature          0
# Humidity             0
# SquareFootage        0
# Occupancy            0
# HVACUsage            0
# LightingUsage        0
# DayOfWeek            0
# Holiday              0
# EnergyConsumption    0
# Weekend              0
# dtype: int64

# %%
df.describe()
# Out:
#                            Date_Time  Temperature     Humidity  SquareFootage  \
# count                           1000  1000.000000  1000.000000    1000.000000
# mean   2022-01-21 19:29:59.999999744    24.982026    45.395412    1500.052488
# min              2022-01-01 00:00:00    20.007565    30.015975    1000.512661
# 25%              2022-01-11 09:45:00    22.645070    38.297722    1247.108548
# 50%              2022-01-21 19:30:00    24.751637    45.972116    1507.967426
# 75%              2022-02-01 05:15:00    27.418174    52.420066    1740.340165
# max              2022-02-11 15:00:00    29.998671    59.969085    1999.982252
# std                              NaN     2.836850     8.518905     288.418873
#
#          Occupancy    HVACUsage  LightingUsage      Holiday  \
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean      4.581000     0.492000       0.491000     0.467000
# min       0.000000     0.000000       0.000000     0.000000
# ...

# %%
df['HVACUsage'].unique()
# Out:
# array([1, 0])

# %%
df['LightingUsage'].unique()
# Out:
# array([0, 1])

# %%
plt.figure(figsize=(15,10))
plt.plot(df['Date_Time'],df['EnergyConsumption'])

# %%
df['DayOfWeek'],_ = pd.factorize(df['DayOfWeek'])

# %%
df['DayOfWeek'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
plt.figure(figsize=(11,11))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_Time          1000 non-null   datetime64[ns]
#  1   Temperature        1000 non-null   float64
#  2   Humidity           1000 non-null   float64
#  3   SquareFootage      1000 non-null   float64
#  4   Occupancy          1000 non-null   int64
#  5   HVACUsage          1000 non-null   int64
#  6   LightingUsage      1000 non-null   int64
#  7   DayOfWeek          1000 non-null   int64
#  8   Holiday            1000 non-null   int64
#  9   EnergyConsumption  1000 non-null   float64
#  10  Weekend            1000 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(6)
# memory usage: 86.1 KB

# %%
df['Year'] = df['Date_Time'].dt.year
df['Month'] = df['Date_Time'].dt.month
df['Day'] = df['Date_Time'].dt.day
df['Hour'] = df['Date_Time'].dt.hour

# %%
print(df.dtypes)
# Out:
# Date_Time            datetime64[ns]
# Temperature                 float64
# Humidity                    float64
# SquareFootage               float64
# Occupancy                     int64
# HVACUsage                     int64
# LightingUsage                 int64
# DayOfWeek                     int64
# Holiday                       int64
# EnergyConsumption           float64
# Weekend                       int64
# Year                          int32
# Month                         int32
# Day                           int32
# Hour                          int32
# dtype: object

# %%
df.head()
# Out:
#             Date_Time  Temperature   Humidity  SquareFootage  Occupancy  \
# 0 2022-01-01 00:00:00    25.139433  43.431581    1565.693999          5
# 1 2022-01-01 01:00:00    27.731651  54.225919    1411.064918          1
# 2 2022-01-01 02:00:00    28.704277  58.907658    1755.715009          2
# 3 2022-01-01 03:00:00    20.080469  50.371637    1452.316318          1
# 4 2022-01-01 04:00:00    23.097359  51.401421    1094.130359          9
#
#    HVACUsage  LightingUsage  DayOfWeek  Holiday  EnergyConsumption  Weekend  \
# 0          1              0          0        0          75.364373        0
# 1          1              1          1        0          83.401855        1
# 2          0              0          2        0          78.270888        1
# 3          0              1          3        0          56.519850        0
# 4          1              0          4        0          70.811732        0
#
#    Year  Month  Day  Hour
# 0  2022      1    1     0
# ...

# %%
df = df.drop(columns=['Weekend','SquareFootage'])

# %%
df = df.drop(columns=['Date_Time'])

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()

# %%
x = df.drop(columns=['EnergyConsumption'])
y = df['EnergyConsumption']

# %%
x
# Out:
#      Temperature   Humidity  Occupancy  HVACUsage  LightingUsage  DayOfWeek  \
# 0      25.139433  43.431581          5          1              0          0
# 1      27.731651  54.225919          1          1              1          1
# 2      28.704277  58.907658          2          0              0          2
# 3      20.080469  50.371637          1          0              1          3
# 4      23.097359  51.401421          9          1              0          4
# ..           ...        ...        ...        ...            ...        ...
# 995    28.619382  48.850160          5          0              0          1
# 996    23.836647  47.256435          4          0              1          6
# 997    23.005340  48.720501          6          0              1          4
# 998    25.138365  31.306459          3          1              0          5
# 999    23.051165  42.615421          6          0              1          1
#
#      Holiday  Year  Month  Day  Hour
# ...

# %%
y
# Out:
# 0      75.364373
# 1      83.401855
# 2      78.270888
# 3      56.519850
# 4      70.811732
#          ...
# 995    82.306692
# 996    66.577320
# 997    72.753471
# 998    76.950389
# 999    71.545311
# Name: EnergyConsumption, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
feature_importances = model.feature_importances_
features = x_train.columns

# Plot
plt.figure(figsize=(10, 6))
plt.barh(features, feature_importances)
plt.xlabel("Feature Importance")
plt.ylabel("Features")
plt.title("Feature Importance Analysis")
plt.show()

# %%
y_pred = model.predict(x_test)

# %%
plt.figure(figsize=(10,10))
plt.scatter(y_test,y_pred,alpha=0.8)
plt.xlabel('actual energy consumption')
plt.ylabel('predicted energy consumption')
plt.title('Actual VS Predicted')
plt.show()

# %%
model.score(x_train,y_train)
# Out:
# 0.9353256234028666

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Occupancy', 'HVACUsage', 'LightingUsage',
#        'DayOfWeek', 'Holiday', 'EnergyConsumption', 'Year', 'Month', 'Day',
#        'Hour'],
#       dtype='object')

# %%
new = pd.DataFrame({'Acutal':y_test,
                    'Predicted':y_pred})
new
# Out:
#         Acutal  Predicted
# 531  77.432435  74.145632
# 73   84.191467  82.116588
# 281  91.490982  87.162002
# 568  74.445589  79.452654
# 453  61.896415  63.964389
# ..         ...        ...
# 822  86.122349  89.794233
# 793  88.546906  82.217942
# 645  77.328511  79.810402
# 147  76.138955  66.362983
# 655  73.024254  70.836493
#
# [200 rows x 2 columns]

# %%
import joblib
joblib.dump(model, 'Energy_Consumption.pkl')
loaded_model = joblib.load('Energy_Consumption.pkl')

# %%
df
# Out:
#      Temperature   Humidity  Occupancy  HVACUsage  LightingUsage  DayOfWeek  \
# 0      25.139433  43.431581          5          1              0          0
# 1      27.731651  54.225919          1          1              1          1
# 2      28.704277  58.907658          2          0              0          2
# 3      20.080469  50.371637          1          0              1          3
# 4      23.097359  51.401421          9          1              0          4
# ..           ...        ...        ...        ...            ...        ...
# 995    28.619382  48.850160          5          0              0          1
# 996    23.836647  47.256435          4          0              1          6
# 997    23.005340  48.720501          6          0              1          4
# 998    25.138365  31.306459          3          1              0          5
# 999    23.051165  42.615421          6          0              1          1
#
#      Holiday  EnergyConsumption  Year  Month  Day  Hour
# ...

# %%
df['Occupancy'].unique()
# Out:
# array([5, 1, 2, 9, 6, 8, 0, 4, 3, 7])

# %%
df['Humidity'].max()
# Out:
# np.float64(59.96908490414602)

# %%
selected_date = st.date_input("Select a date")
    year = selected_date.year
    month = selected_date.month
    day = selected_date.day
    date = f'{month}-{day}-{year}'
